# %%
# !pip install opencv-contrib-python

# %%
# !git clone https://github.com/subhamroy021/Facial-Recognition.git
# Out:
# fatal: destination path 'Facial-Recognition' already exists and is not an empty directory.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: BCF8-FA59
#
#  C:\Users\82104\Facial-Recognition-master 디렉터리
#
# 2021-03-02(화)  오후 10:32    <DIR>          .
# 2021-03-02(화)  오후 10:32    <DIR>          ..
# 2021-03-02(화)  오후 09:57    <DIR>          .ipynb_checkpoints
# 2021-03-02(화)  오후 10:30             7,067 Capture and Recognition.ipynb
# 2021-03-02(화)  오후 10:27    <DIR>          color_faces
# 2021-03-02(화)  오후 10:27    <DIR>          faces
# 2021-03-02(화)  오후 10:32             1,324 Facial_Recognition_Part1.py
# 2021-03-02(화)  오후 10:12               631 Facial_Recognition_Part2.py
# 2021-03-02(화)  오후 10:21             2,141 Facial_Recognition_Part3.py
# 2021-03-02(화)  오후 10:17    <DIR>          Facial-Recognition
# 2021-03-02(화)  오후 10:08           963,441 haarcascade_frontalface_default.xml
#                5개 파일             974,604 바이트
#                6개 디렉터리  64,043,069,440 바이트 남음

# %%
mkdir faces
# Out:
# 하위 디렉터리 또는 파일 faces이(가) 이미 있습니다.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: BCF8-FA59
#
#  C:\Users\82104\Facial-Recognition-master 디렉터리
#
# 2021-03-02(화)  오후 10:32    <DIR>          .
# 2021-03-02(화)  오후 10:32    <DIR>          ..
# 2021-03-02(화)  오후 09:57    <DIR>          .ipynb_checkpoints
# 2021-03-02(화)  오후 10:30             7,067 Capture and Recognition.ipynb
# 2021-03-02(화)  오후 10:27    <DIR>          color_faces
# 2021-03-02(화)  오후 10:27    <DIR>          faces
# 2021-03-02(화)  오후 10:32             1,324 Facial_Recognition_Part1.py
# 2021-03-02(화)  오후 10:12               631 Facial_Recognition_Part2.py
# 2021-03-02(화)  오후 10:21             2,141 Facial_Recognition_Part3.py
# 2021-03-02(화)  오후 10:17    <DIR>          Facial-Recognition
# 2021-03-02(화)  오후 10:08           963,441 haarcascade_frontalface_default.xml
#                5개 파일             974,604 바이트
#                6개 디렉터리  64,043,069,440 바이트 남음

# %%
# !python3 Facial_Recognition_Part1.py
# Out:
# Face not Found
# C:\Users\82104\Facial-Recognition-master\Facial_Recognition_Part1.py:10: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is():
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# Face not Found
# ...

# %%
# !python3 Facial_Recognition_Part2.py
# Out:
# Model Training Complete!!!!!

# %%
# !python3 Facial_Recognition_Part3.py
# Out:
# C:\Users\82104\Facial-Recognition-master\Facial_Recognition_Part3.py:31: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is():
